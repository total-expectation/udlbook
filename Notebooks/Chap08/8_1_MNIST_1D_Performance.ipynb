# %% [markdown]
# <a href="https://colab.research.google.com/github/udlbook/udlbook/blob/main/Notebooks/Chap08/8_1_MNIST_1D_Performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.1: MNIST_1D_Performance**
#
# This notebook runs a simple neural network on the MNIST1D dataset as in figure 8.2a. It uses code from https://github.com/greydanus/mnist1d to generate the data.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TO DO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d

# %% [markdown]
# Let's generate a training and test dataset using the MNIST1D code.  The dataset gets saved as a .pkl file so it doesn't have to be regenerated each time.

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Successfully loaded data from ./mnist1d_data.pkl
# Examples in training set: 4000
# Examples in test set: 4000
# Length of each example: 40

# %%
D_i = 40    # Input dimensions
D_k = 100   # Hidden dimensions
D_o = 10    # Output dimensions
# TODO:
# Define a model with two hidden layers of size 100
# And ReLU activations between them
# Replace this line (see Figure 7.8 of book for help):
model = torch.nn.Sequential(
  torch.nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o)
)


def weights_init(layer_in):
  # TO DO:
  # Initialize the parameters with He initialization
  # Replace this line (see figure 7.8 of book for help)
  print("Initializing layer")


# Call the function you just defined
model.apply(weights_init)
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Sequential(
#   (0): Linear(in_features=40, out_features=100, bias=True)
#   (1): ReLU()
#   (2): Linear(in_features=100, out_features=100, bias=True)
#   (3): ReLU()
#   (4): Linear(in_features=100, out_features=10, bias=True)
# )

# %%
# choose cross entropy loss function (equation 5.24)
loss_function = torch.nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.5, momentum=0.9)
# object that decreases learning rate by half every 10 epochs
scheduler = StepLR(optimizer, step_size=10, gamma=0.5)
x_train = torch.tensor(data['x'].astype('float32'))
y_train = torch.tensor(data['y'].transpose().astype('long'))
x_test= torch.tensor(data['x_test'].astype('float32'))
y_test = torch.tensor(data['y_test'].astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 50
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_test = np.zeros((n_epoch))
errors_test = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, batch in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = batch
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch.long())
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_test = model(x_test)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_test_class = torch.max(pred_test.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_test[epoch]= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
  losses_train[epoch] = loss_function(pred_train, y_train.long()).item()
  losses_test[epoch]= loss_function(pred_test, y_test.long()).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  test loss {losses_test[epoch]:.6f}, test error {errors_test[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Initializing layer
# Epoch     0, train loss 1.837886, train error 67.65,  test loss 1.844605, test error 68.85
# Epoch     1, train loss 1.810580, train error 66.72,  test loss 1.830967, test error 67.70
# Epoch     2, train loss 1.766860, train error 65.85,  test loss 1.790241, test error 66.35
# Epoch     3, train loss 1.486799, train error 58.55,  test loss 1.558133, test error 61.38
# Epoch     4, train loss 1.564951, train error 56.55,  test loss 1.677894, test error 60.50
# Epoch     5, train loss 1.670433, train error 61.83,  test loss 1.729715, test error 62.58
# Epoch     6, train loss 1.982695, train error 65.80,  test loss 2.077738, test error 67.72
# Epoch     7, train loss 2.005981, train error 70.78,  test loss 2.054566, test error 71.10
# Epoch     8, train loss 1.772123, train error 68.03,  test loss 1.834773, test error 69.65
# Epoch     9, train loss 1.947406, train error 73.20,  test loss 1.990316, test error 74.97
# Epoch    10, train loss 1.442082, train error 57.65,  test loss 1.555030, test error 60.42
# Epoch    11, train loss 1.187831, train error 49.08,  test loss 1.386029, test error 54.03
# Epoch    12, train loss 1.108021, train error 44.72,  test loss 1.337008, test error 49.95
# Epoch    13, train loss 0.952845, train error 38.85,  test loss 1.190414, test error 44.95
# Epoch    14, train loss 0.914238, train error 36.65,  test loss 1.197199, test error 44.88
# Epoch    15, train loss 0.849572, train error 35.35,  test loss 1.194549, test error 44.10
# Epoch    16, train loss 0.823194, train error 32.75,  test loss 1.217594, test error 44.53
# Epoch    17, train loss 0.760665, train error 30.65,  test loss 1.175669, test error 41.67
# Epoch    18, train loss 0.697492, train error 27.75,  test loss 1.177040, test error 41.10
# Epoch    19, train loss 0.793206, train error 30.82,  test loss 1.306258, test error 42.88
# Epoch    20, train loss 0.493674, train error 19.28,  test loss 1.038827, test error 37.22
# Epoch    21, train loss 0.406178, train error 15.25,  test loss 1.085113, test error 34.47
# Epoch    22, train loss 0.355844, train error 13.55,  test loss 1.125706, test error 34.78
# Epoch    23, train loss 0.348572, train error 13.10,  test loss 1.180334, test error 34.85
# Epoch    24, train loss 0.299745, train error 10.78,  test loss 1.245232, test error 35.55
# Epoch    25, train loss 0.309083, train error 11.85,  test loss 1.215196, test error 34.85
# Epoch    26, train loss 0.270139, train error 10.18,  test loss 1.249919, test error 34.60
# Epoch    27, train loss 0.249623, train error 8.90,  test loss 1.318807, test error 34.38
# Epoch    28, train loss 0.224049, train error 8.00,  test loss 1.327877, test error 33.60
# Epoch    29, train loss 0.227647, train error 7.85,  test loss 1.332599, test error 34.60
# Epoch    30, train loss 0.152639, train error 4.45,  test loss 1.339571, test error 33.40
# Epoch    31, train loss 0.116566, train error 2.62,  test loss 1.384941, test error 33.20
# Epoch    32, train loss 0.110176, train error 3.10,  test loss 1.443791, test error 32.90
# Epoch    33, train loss 0.093505, train error 1.88,  test loss 1.467395, test error 32.80
# Epoch    34, train loss 0.085649, train error 1.53,  test loss 1.519133, test error 32.40
# Epoch    35, train loss 0.077395, train error 1.53,  test loss 1.541564, test error 33.05
# Epoch    36, train loss 0.067379, train error 0.97,  test loss 1.587517, test error 32.85
# Epoch    37, train loss 0.062323, train error 1.07,  test loss 1.621567, test error 32.93
# Epoch    38, train loss 0.058539, train error 0.78,  test loss 1.651897, test error 32.68
# Epoch    39, train loss 0.051346, train error 0.60,  test loss 1.684310, test error 32.80
# Epoch    40, train loss 0.046331, train error 0.53,  test loss 1.704397, test error 32.72
# Epoch    41, train loss 0.043708, train error 0.50,  test loss 1.716654, test error 32.68
# Epoch    42, train loss 0.041956, train error 0.40,  test loss 1.743619, test error 32.90
# Epoch    43, train loss 0.040340, train error 0.38,  test loss 1.754203, test error 32.78
# Epoch    44, train loss 0.038613, train error 0.32,  test loss 1.774326, test error 33.12
# Epoch    45, train loss 0.037468, train error 0.30,  test loss 1.792016, test error 32.90
# Epoch    46, train loss 0.035688, train error 0.30,  test loss 1.805464, test error 33.07
# Epoch    47, train loss 0.034887, train error 0.20,  test loss 1.823546, test error 32.95
# Epoch    48, train loss 0.033451, train error 0.30,  test loss 1.833671, test error 32.78
# Epoch    49, train loss 0.032259, train error 0.25,  test loss 1.844755, test error 32.88

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_test,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Test Error %3.2f'%(errors_train[-1],errors_test[-1]))
ax.legend()
plt.show()

# Plot the results
fig, ax = plt.subplots()
ax.plot(losses_train,'r-',label='train')
ax.plot(losses_test,'b-',label='test')
ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Loss')
ax.set_title('Train loss %3.2f, Test loss %3.2f'%(losses_train[-1],losses_test[-1]))
ax.legend()
plt.show()

# %% [markdown]
# **TO DO**
#
# Play with the model -- try changing the number of layers, hidden units, learning rate, batch size, momentum or anything else you like.  See if you can improve the test results.
#
# Is it a good idea to optimize the hyperparameters in this way?  Will the final result be a good estimate of the true test performance?

# %% [markdown]
# <span style="color:green;white-space:pre-wrap">It's just hyperparameter optimization, which involves alot of trial and error by hand, obviously it's not a guaranteed way of achieving good results, but with some patience it can still go a long way. </span>
